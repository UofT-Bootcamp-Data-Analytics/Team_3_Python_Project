# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import numpy as np
import csv

# read data
food_data = './data/food-prices.csv' 
foodPriceData = pd.read_csv(food_data)
food_expenditure_data = './data/Average_food_expenditure_per_household.csv'
foodExpenditureData = pd.read_csv(food_expenditure_data)

food_expense_data = './data/food-expenses.csv' 
foodExpensesData = pd.read_csv(food_expense_data)




# clean foodExpenditureData
foodExpenditureData['Average expenditure per household'] = foodExpenditureData['Average expenditure per household'].str.replace(",", "").str.replace("F", "0").astype(float)
foodExpenditureData['Year'] = foodExpenditureData["Year"].astype(int)

#clean food expendure data
foodExpensesData = foodExpensesData[['REF_DATE', 'Products and product groups', 'VALUE']].copy()
foodExpensesData = foodExpensesData.rename(columns={'REF_DATE': 'Year', 'Products and product groups': 'Products'})
foodExpensesData = foodExpensesData[foodExpensesData['Year'].str.contains('Dec')]
foodExpensesData['Year'] = foodExpensesData['Year'].map(lambda x: x.replace("Dec-", "20"))
foodExpensesData['Year'] = foodExpensesData['Year'].astype(int)

# Get only fish data
salmonExpensesData = foodExpensesData[foodExpensesData['Products'].str.contains(' fish')]
#clean foodPriceData
foodPriceData = foodPriceData.rename(columns={'REF_DATE': 'Year'})
foodPriceData.head()
# salmonExpensesData.head()
# Out:
#       Year     GEO           DGUID                             Products  \
# 0  2017-01  Canada  2016A000011124      Beef stewing cuts, per kilogram
# 1  2017-01  Canada  2016A000011124    Beef striploin cuts, per kilogram
# 2  2017-01  Canada  2016A000011124  Beef top sirloin cuts, per kilogram
# 3  2017-01  Canada  2016A000011124          Beef rib cuts, per kilogram
# 4  2017-01  Canada  2016A000011124            Ground beef, per kilogram
#
#        UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  COORDINATE  VALUE  \
# 0  Dollars      81         units          0  v1353834271       11.10  12.66
# 1  Dollars      81         units          0  v1353834272       11.20  21.94
# 2  Dollars      81         units          0  v1353834273       11.30  13.44
# 3  Dollars      81         units          0  v1353834311       11.41  20.17
# 4  Dollars      81         units          0  v1353834274       11.40   9.12
#
#    STATUS  SYMBOL  TERMINATED  DECIMALS
# 0     NaN     NaN         NaN         2
# 1     NaN     NaN         NaN         2
# 2     NaN     NaN         NaN         2
# 3     NaN     NaN         NaN         2
# 4     NaN     NaN         NaN         2

# %%
# Filter by Canada, and get relavent columns
canadaData = foodPriceData[foodPriceData['GEO'] == 'Canada'][['Year', 'Products','VALUE']]
canadaData = canadaData[canadaData["Year"].str.contains("-12")]
canadaData['Year'] = canadaData['Year'].map(lambda x: x.replace("-12", "") )
canadaData['Year'] = canadaData['Year'].astype(int)
canadaData.head()
# Out:
#        Year                             Products  VALUE
# 13299  2017      Beef stewing cuts, per kilogram  13.90
# 13300  2017    Beef striploin cuts, per kilogram  18.07
# 13301  2017  Beef top sirloin cuts, per kilogram  10.40
# 13302  2017          Beef rib cuts, per kilogram  14.96
# 13303  2017            Ground beef, per kilogram   9.06

# %%
removeProductsFrom = [
    "beef", 
    "pork",
    "chicken",
    "bacon",
    "wieners",
    "shrimp",
    "canned tuna",
    "meatless burgers",
    "milk",
    "cream",
    "butter",
    "margarine",
    "yogurt",
    "eggs",
    # "apples",
    # "oranges",
    # "bananas",
    # "lemons",
    # "limes",
    # "grapes",
    # "cantaloupe",
    # "avocado",
    # "sweet potatoes",
    # "cabbage",
    # "carrots",
    # "onions",
    # "celery",
    # "cucumber",
    # "mushrooms",
    # "peppers",
    # "squash",
    # "salad greens",
    "white bread",
    "flatbread and pita",
    "dry or fresh pasta",
    "brown rice",
    "white rice",
    "cereal",
    "wheat flour",
    "white sugar",
    "apple juice",
    "orange juice",
    "coffee",
    "tea",
    "vegetable oil",
    "canola oil",
    "olive oil",
    "baby food",
    "infant formula",
    "peanut butter",
    "mayonnaise",
    "tofu",
    "hummus",
    "salsa",
    "almonds",
    "peanuts",
    "sunflower seeds",
    "deodorant",
    "toothpaste",
    "shampoo",
    "laundry detergent"
]

freshFruits = [ 
    "apples",
    "oranges",
    "bananas",
    "lemons",
    "limes",
    "grapes",
    "cantaloupe",
    "avocado",
    "cucumber",
    "peppers",
    "stawberrries",
    "pears" 
]

freshVegs = [
    "sweet potatoes",
    "cabbage",
    "carrots",
    "onions",
    "celery",
    "mushrooms",
    "squash",
    "salad greens",
    "tomatoes",
    "romaine lettuce", 
    "potatoes", 
    "iceberg lettuce",
    "brococoli"
]

others = ['salmon, canned, frozen']
canadaData['Products'] = canadaData['Products'].str.lower()
filterByProducts = canadaData
for product in removeProductsFrom: 
    # print(product)
    filterByProducts = filterByProducts[filterByProducts['Products'].str.contains(product) == False]
filterByProducts.head()
# Out:
#        Year                  Products  VALUE
# 13313  2017      salmon, per kilogram  20.19
# 13315  2017  canned salmon, 213 grams   3.25
# 13326  2017   block cheese, 500 grams   5.42
# 13329  2017      apples, per kilogram   3.95
# 13330  2017     oranges, per kilogram   3.36

# %%
tempData = filterByProducts.copy()

notFruits = removeProductsFrom.append(others).append()
freshFruitData = pd.DataFrame(columns=['Year', 'Products', 'VALUE'])
# df2=filterByProducts.apply(lambda col: col.contains('apples|oranges', na=False), axis=1)

# freshFruitData['Products'] = freshFruitData['Products'].filter(lambda x: x.split(',')[0].isin(freshFruits))
for fruit in freshFruits:
    x = tempData.filter(like=fruit, axis=0)
    print(fruit)
    freshFruitData['Products'] = freshFruitData['Products']
df2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 3
#       1 tempData = filterByProducts.copy()
# ----> 3 notFruits = removeProductsFrom.append(others).append(freshVegs)
#       4 freshFruitData = pd.DataFrame(columns=['Year', 'Products', 'VALUE'])
#       5 # df2=filterByProducts.apply(lambda col: col.contains('apples|oranges', na=False), axis=1)
#       6
#       7 # freshFruitData['Products'] = freshFruitData['Products'].filter(lambda x: x.split(',')[0].isin(freshFruits))
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
dataByProduct = filterByProducts.pivot(index='Year', columns='Products', values='VALUE')
dataByProduct.head()
# Out:
# Products  block cheese, 500 grams  broccoli, unit  \
# Year
# 2017                         5.42            2.41
# 2018                         5.36            2.97
# 2019                         5.53            2.52
# 2020                         6.06            2.69
# 2021                         6.03            3.04
#
# Products  canned baked beans, 398 millilitres  \
# Year
# 2017                                     1.27
# 2018                                     1.16
# 2019                                     1.20
# 2020                                     1.33
# 2021                                     1.47
#
# Products  canned beans and lentils, 540 millilitres  \
# Year
# 2017                                           1.16
# 2018                                           1.19
# 2019                                           1.24
# 2020                                           1.28
# 2021                                           1.39
#
# Products  canned corn, 341 millilitres  canned peach, 398 millilitres  \
# Year
# 2017                              1.01                           2.00
# 2018                              1.01                           2.16
# 2019                              1.12                           2.26
# 2020                              1.15                           2.15
# 2021                              1.17                           2.14
#
# Products  canned pear, 398 millilitres  canned salmon, 213 grams  \
# Year
# 2017                              2.05                      3.25
# 2018                              2.13                      3.77
# 2019                              2.21                      4.28
# 2020                              2.34                      4.64
# 2021                              2.23                      4.68
#
# Products  canned soup, 284 millilitres  canned tomatoes, 796 millilitres  ...  \
# Year                                                                      ...
# 2017                              1.13                              1.42  ...
# 2018                              1.15                              1.40  ...
# 2019                              1.17                              1.34  ...
# 2020                              1.21                              1.46  ...
# 2021                              1.23                              1.60  ...
#
# Products  ketchup, 1 litre  pasta sauce, 650 millilitres  pears, per kilogram  \
# Year
# 2017                  3.30                          2.16                 3.92
# 2018                  3.41                          2.35                 3.95
# 2019                  3.23                          2.27                 4.56
# 2020                  3.39                          2.42                 4.78
# 2021                  3.85                          2.65                 5.01
#
# Products  potatoes, 4.54 kilograms  potatoes, per kilogram  \
# Year
# 2017                          3.72                    3.29
# 2018                          4.19                    3.63
# 2019                          4.03                    4.09
# 2020                          3.87                    4.15
# 2021                          4.22                    4.21
#
# Products  romaine lettuce, unit  salad dressing, 475 millilitres  \
# Year
# 2017                       2.22                             2.41
# 2018                       3.31                             2.38
# 2019                       3.04                             2.40
# 2020                       3.25                             2.61
# 2021                       3.23                             3.15
#
# Products  salmon, per kilogram  strawberries, 454 grams  \
# Year
# 2017                     20.19                     3.72
# 2018                     22.63                     6.06
# 2019                     22.83                     6.24
# 2020                     20.35                     5.03
# 2021                     23.46                     5.79
#
# Products  tomatoes, per kilogram
# Year
# 2017                        5.30
# 2018                        6.04
# 2019                        5.95
# 2020                        5.95
# 2021                        5.59
#
# [5 rows x 34 columns]

# %%
dataByProduct.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
salmonStudy = dataByProduct[['canned salmon, 213 grams', 'salmon, per kilogram']].copy()
salmonStudy['canned salmon, 213 grams'] = salmonStudy['canned salmon, 213 grams'].apply(lambda x: x*1000/213)
salmonStudy = salmonStudy.rename(columns={'canned salmon, 213 grams': 'canned salmon, per kilogram'})
salmonStudy.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
salmonExpenditureData = foodExpenditureData[foodExpenditureData["Category"].str.contains('Salmon')]
salmonExpenditureData = salmonExpenditureData.pivot(index='Year', columns='Category', values='Average expenditure per household')
salmonExpenditureData.head()
# salmonExpenditureData.plot()
# Out:
# Category  Salmon (canned)  Salmon (fresh or frozen, uncooked)
# Year
# 2015                  8.0                                54.0
# 2016                  5.0                                45.0
# 2017                  9.0                                44.0
# 2019                 11.0                                57.0

# %%
# salmonFullStudy = pd.merge(salmonStudy, salmonExpenditureData, on='Year', how='inner')
salmonExpensesData = salmonExpensesData.pivot(index='Year', columns='Products', values='VALUE')


salmonFullStudy = pd.merge(salmonStudy, salmonExpensesData, on='Year', how='inner')


fig, ax = plt.subplots()

ax.plot(salmonFullStudy)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.legend(['Canned Salmon Price', 'Fresh Salmon Price', 'Canned Salmon Expenditure', 'Fresh Salmon Expenditure'],loc='best')
plt.show()

# %%
salmonFullStudy.head()
# Out:
# Products  canned salmon, per kilogram  salmon, per kilogram  \
# Year
# 2017                        15.258216                 20.19
# 2018                        17.699531                 22.63
# 2019                        20.093897                 22.83
# 2020                        21.784038                 20.35
# 2021                        21.971831                 23.46
#
# Products  Canned and other preserved fish  \
# Year
# 2017                                146.4
# 2018                                153.1
# 2019                                163.1
# 2020                                167.2
# 2021                                165.9
#
# Products  Fresh or frozen fish (including portions and fish sticks)
# Year
# 2017                                                  145.5
# 2018                                                  150.9
# 2019                                                  156.6
# 2020                                                  153.7
# 2021                                                  161.0
