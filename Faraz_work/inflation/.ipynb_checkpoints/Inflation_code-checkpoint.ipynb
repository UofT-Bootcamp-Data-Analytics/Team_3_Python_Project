# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statistics import mean

# %%
# data load and cleaning
DF_data = pd.read_csv("data/CPI_seperated.csv", index_col='products')
DF_data.rename(index={'Food 5':'Food','Shelter 6':'Shelter',
                      'Alcoholic beverages, tobacco products and recreational cannabis':'Alcohol, tobacco, recreational cannabis',
                      'All-items excluding food and energy 7':'All-items excluding food and energy',
                      'All-items excluding energy 7':'All-items excluding energy',
                     'Energy 7':'Energy',
                     'Goods 8':'Goods',
                     'Services 9':'Services'},inplace=True)
DF_data
# Out:
#                                                   2015   2016   2017   2018  \
# products
# Food                                             140.5  142.6  142.7  145.3
# Shelter                                          133.7  135.8  138.1  140.9
# Household operations, furnishings and equipment  119.7  121.7  121.9  123.2
# Clothing and footwear                             94.6   94.4   93.7   94.5
# Transportation                                   126.5  127.9  132.9  139.1
# Gasoline                                         153.4  144.2  161.2  181.5
# Health and personal care                         120.5  122.2  124.3  125.9
# Recreation, education and reading                109.4  111.3  114.0  115.3
# Alcohol, tobacco, recreational cannabis          152.0  156.8  161.1  167.9
# All-items excluding food and energy              121.2  123.5  125.5  127.9
# All-items excluding energy                       124.6  126.9  128.5  131.0
# Energy                                           149.5  145.0  152.7  162.9
# Goods                                            116.8  117.9  118.9  121.1
# Services                                         136.4  138.9  142.0  145.8
# All-items                                        126.6  128.4  130.4  133.4
#
#                                                   2019   2020   2021   2022
# products
# Food                                             150.2  153.7  157.5  171.5
# Shelter                                          144.5  147.0  152.7  163.3
# Household operations, furnishings and equipment  123.6  123.8  125.2  130.9
# Clothing and footwear                             96.1   94.4   94.1   95.4
# Transportation                                   141.5  141.2  151.4  167.5
# Gasoline                                         170.5  146.7  192.4  247.2
# Health and personal care                         127.4  129.2  132.6  138.0
# Recreation, education and reading                116.8  115.7  117.9  123.5
# Alcohol, tobacco, recreational cannabis          171.1  171.9  175.0  181.3
# All-items excluding food and energy              130.5  132.0  135.1  141.8
# All-items excluding energy                       134.0  135.8  139.0  146.9
# Energy                                           159.3  147.2  175.0  214.4
# Goods                                            122.7  122.5  128.3  139.4
# Services                                         149.2  151.3  154.8  162.6
# All-items                                        136.0  137.0  141.6  151.2

# %%
# calculatig the inflation rate for every category by getting the cpi for every category and using the iflation rate formula to 
# get the each inflationrate
years = [i for i in DF_data]
products = [i for i in DF_data.index]
products_CPI_list = []
for x in range(len(products)):
    category = products[x]
    CPI_List = [DF_data.loc[f"{category}", f"{year}"] for year in years]
#     print(CPI_List)
    products_CPI_list.append(CPI_List)
print(products_CPI_list)
# Out:
# [[140.5, 142.6, 142.7, 145.3, 150.2, 153.7, 157.5, 171.5], [133.7, 135.8, 138.1, 140.9, 144.5, 147.0, 152.7, 163.3], [119.7, 121.7, 121.9, 123.2, 123.6, 123.8, 125.2, 130.9], [94.6, 94.4, 93.7, 94.5, 96.1, 94.4, 94.1, 95.4], [126.5, 127.9, 132.9, 139.1, 141.5, 141.2, 151.4, 167.5], [153.4, 144.2, 161.2, 181.5, 170.5, 146.7, 192.4, 247.2], [120.5, 122.2, 124.3, 125.9, 127.4, 129.2, 132.6, 138.0], [109.4, 111.3, 114.0, 115.3, 116.8, 115.7, 117.9, 123.5], [152.0, 156.8, 161.1, 167.9, 171.1, 171.9, 175.0, 181.3], [121.2, 123.5, 125.5, 127.9, 130.5, 132.0, 135.1, 141.8], [124.6, 126.9, 128.5, 131.0, 134.0, 135.8, 139.0, 146.9], [149.5, 145.0, 152.7, 162.9, 159.3, 147.2, 175.0, 214.4], [116.8, 117.9, 118.9, 121.1, 122.7, 122.5, 128.3, 139.4], [136.4, 138.9, 142.0, 145.8, 149.2, 151.3, 154.8, 162.6], [126.6, 128.4, 130.4, 133.4, 136.0, 137.0, 141.6, 151.2]]

# %%
# plotting the first plot for each category
plt.figure(figsize=(15, 8))
for i in range(len(products)):
    plt.plot(years, products_CPI_list[i], alpha=0.75, mouseover=True)

plt.axvline(x ='2020', color='black',alpha=0.70, linestyle='--', linewidth=2, label='Covid_line' )
covid_line_point=['2020', max(max(i) for i in products_CPI_list)]
plt.text(covid_line_point[0] ,covid_line_point[1],'covid_line')
plt.title("Annual Consumer Price Index Per Year")
plt.xlabel("Year")
plt.ylabel("CPI (Consume Price Index)")
plt.xlim(min(years),max(years))
# plt.grid(True)
plt.legend(labels=products, loc='best')
plt.savefig('outcomes/cpi_per year')
plt.show()
